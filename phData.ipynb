# %% [markdown]
# #Cloud Data Developer - Project Challenge 2021
# By John Thomason

# %% [markdown]
# ## Purpose
# To Investigate the benefits of the cloud-native platforms Databricks and Snowflake platforms using the datasets provided by Northwoods Airlines.
# To do this, we first load the datasets into Databricks to create reports requested by Northwoods Airlines. Next we load the data from Databricks into Snowflake and create Views in Snowflake to display the data the same as we do in the Databricks reports.

# %% [markdown]
# ## 1. Load the Data into Databricks

# %% [markdown]
# #### Create Airlines Table from Airlines Dataset

# %%
# %python

airlines_df = spark.read.format("csv").load("dbfs:/FileStore/shared_uploads/thom4236@stthomas.edu/airlines.csv", header="true", inferSchema="true")
airlines_df.cache()
display(airlines_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>IATA_CODE</th><th>AIRLINE</th></tr></thead><tbody><tr><td>UA</td><td>United Air Lines Inc.</td></tr><tr><td>AA</td><td>American Airlines Inc.</td></tr><tr><td>US</td><td>US Airways Inc.</td></tr><tr><td>F9</td><td>Frontier Airlines Inc.</td></tr><tr><td>B6</td><td>JetBlue Airways</td></tr><tr><td>OO</td><td>Skywest Airlines Inc.</td></tr><tr><td>AS</td><td>Alaska Airlines Inc.</td></tr><tr><td>NK</td><td>Spirit Air Lines</td></tr><tr><td>WN</td><td>Southwest Airlines Co.</td></tr><tr><td>DL</td><td>Delta Air Lines Inc.</td></tr><tr><td>EV</td><td>Atlantic Southeast Airlines</td></tr><tr><td>HA</td><td>Hawaiian Airlines Inc.</td></tr><tr><td>MQ</td><td>American Eagle Airlines Inc.</td></tr><tr><td>VX</td><td>Virgin America</td></tr></tbody></table></div>

# %% [markdown]
# #### Create Airports Table from Airports Dataset

# %%
airports_df = spark.read.format("csv").load("dbfs:/FileStore/shared_uploads/thom4236@stthomas.edu/airports.csv", header="true", inferSchema="true")
airports_df.cache() # Cache data for faster reuse
display(airports_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>IATA_CODE</th><th>AIRPORT</th><th>CITY</th><th>STATE</th><th>COUNTRY</th><th>LATITUDE</th><th>LONGITUDE</th></tr></thead><tbody><tr><td>ABE</td><td>Lehigh Valley International Airport</td><td>Allentown</td><td>PA</td><td>USA</td><td>40.65236</td><td>-75.4404</td></tr><tr><td>ABI</td><td>Abilene Regional Airport</td><td>Abilene</td><td>TX</td><td>USA</td><td>32.41132</td><td>-99.6819</td></tr><tr><td>ABQ</td><td>Albuquerque International Sunport</td><td>Albuquerque</td><td>NM</td><td>USA</td><td>35.04022</td><td>-106.60919</td></tr><tr><td>ABR</td><td>Aberdeen Regional Airport</td><td>Aberdeen</td><td>SD</td><td>USA</td><td>45.44906</td><td>-98.42183</td></tr><tr><td>ABY</td><td>Southwest Georgia Regional Airport</td><td>Albany</td><td>GA</td><td>USA</td><td>31.53552</td><td>-84.19447</td></tr><tr><td>ACK</td><td>Nantucket Memorial Airport</td><td>Nantucket</td><td>MA</td><td>USA</td><td>41.25305</td><td>-70.06018</td></tr><tr><td>ACT</td><td>Waco Regional Airport</td><td>Waco</td><td>TX</td><td>USA</td><td>31.61129</td><td>-97.23052</td></tr><tr><td>ACV</td><td>Arcata Airport</td><td>Arcata/Eureka</td><td>CA</td><td>USA</td><td>40.97812</td><td>-124.10862
flights_df = spark.read.format("csv").load("dbfs:/FileStore/shared_uploads/thom4236@stthomas.edu/flights/*.csv", header="true", inferSchema="true")
flights_df_fix = flights_df.withColumn("FLIGHT_NUMBER_STR", flights_df['FLIGHT_NUMBER'].cast('string')).drop('FLIGHT_NUMBER').withColumnRenamed('FLIGHT_NUMBER_STR', 'FLIGHT_NUMBER')
flights_df_fix = flights_df_fix.withColumn("SCHEDULED_DEPARTURE_STR", flights_df_fix['SCHEDULED_DEPARTURE'].cast('string')).drop('SCHEDULED_DEPARTURE').withColumnRenamed('SCHEDULED_DEPARTURE_STR', 'SCHEDULED_DEPARTURE')
flights_df_fix = flights_df_fix.withColumn("DEPARTURE_TIME_STR", flights_df_fix['DEPARTURE_TIME'].cast('string')).drop('DEPARTURE_TIME').withColumnRenamed('DEPARTURE_TIME_STR', 'DEPARTURE_TIME')
flights_df_fix = flights_df_fix.withColumn("WHEELS_OFF_STR", flights_df_fix['WHEELS_OFF'].cast('string')).drop('WHEELS_OFF').withColumnRenamed('WHEELS_OFF_STR', 'WHEELS_OFF')
flights_df_fix = flights_df_fix.withColumn("ARRIVAL_TIME_STR", flights_df_fix['ARRIVAL_TIME'].cast('string')).drop('ARRIVAL_TIME').withColumnRenamed('ARRIVAL_TIME_STR', 'ARRIVAL_TIME')
flights_df_fix = flights_df_fix.withColumn("ARRIVAL_DELAY_STR", flights_df_fix['ARRIVAL_DELAY'].cast('string')).drop('ARRIVAL_DELAY').withColumnRenamed('ARRIVAL_DELAY_STR', 'ARRIVAL_DELAY')
flights_df = flights_df_fix
flights_df.cache()
display(flights_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>YEAR</th><th>MONTH</th><th>DAY</th><th>DAY_OF_WEEK</th><th>AIRLINE</th><th>TAIL_NUMBER</th><th>ORIGIN_AIRPORT</th><th>DESTINATION_AIRPORT</th><th>DEPARTURE_DELAY</th><th>TAXI_OUT</th><th>SCHEDULED_TIME</th><th>ELAPSED_TIME</th><th>AIR_TIME</th><th>DISTANCE</th><th>WHEELS_ON</th><th>TAXI_IN</th><th>SCHEDULED_ARRIVAL</th><th>DIVERTED</th><th>CANCELLED</th><th>CANCELLATION_REASON</th><th>AIR_SYSTEM_DELAY</th><th>SECURITY_DELAY</th><th>AIRLINE_DELAY</th><th>LATE_AIRCRAFT_DELAY</th><th>WEATHER_DELAY</th><th>FLIGHT_NUMBER</th><th>SCHEDULED_DEPARTURE</th><th>DEPARTURE_TIME</th><th>WHEELS_OFF</th><th>ARRIVAL_TIME</th><th>ARRIVAL_DELAY</th></tr></thead><tbody><tr><td>2015</td><td>7</td><td>1</td><td>3</td><td>MQ</td><td>N935MQ</td><td>DFW</td><td>CID</td><td>16</td><td>12</td><td>124</td><td>119</td><td>103</td><td>685</td><td>1359</td><td>4</td><td>1352</td><td>0</td><td>0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>3029</td><td>1148</td><td>1204</td><td>1216</td><td>1403</td><td>11</td></tr><tr><td>2015</td><td>7</td><td>1</td><td>3</td><td>MQ</td><td>N690MQ</td><td>DFW</td><td>MLI</td><td>32</td><td>12</td><td>122</td><td>116</td><td>101</td><td>691</td><td>1414</td><td>3</td><td>1351</td><td>0</td><td>0</td><td>null</td><td>0</td><td>0</td><td>26</td><td>0</
UNION ALL
SELECT AIRLINE, AIRPORT, MONTH, YEAR, ORIGIN_OR_DESTINATION, SUM(Flight) FLIGHTS from
(select ar.AIRLINE, ap.AIRPORT, f.MONTH, f.YEAR, 'DESTINATION' as ORIGIN_OR_DESTINATION, 1 as Flight from airlines ar, airports ap, flights f where ar.IATA_CODE = f.AIRLINE and ap.IATA_CODE = f.DESTINATION_AIRPORT)
GROUP BY AIRLINE,AIRPORT,MONTH,YEAR,ORIGIN_OR_DESTINATION
ORDER BY AIRLINE,AIRPORT,MONTH,YEAR,ORIGIN_OR_DESTINATION;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AIRLINE</th><th>AIRPORT</th><th>MONTH</th><th>YEAR</th><th>ORIGIN_OR_DESTINATION</th><th>FLIGHTS</th></tr></thead><tbody><tr><td>Alaska Airlines Inc.</td><td>Adak Airport</td><td>1</td><td>2015</td><td>DESTINATION</td><td>9</td></tr><tr><td>Alaska Airlines Inc.</td><td>Adak Airport</td><td>1</td><td>2015</td><td>ORIGIN</td><td>9</td></tr><tr><td>Alaska Airlines Inc.</td><td>Adak Airport</td><td>2</td><td>2015</td><td>DESTINATION</td><td>8</td></tr><tr><td>Alaska Airlines Inc.</td><td>Adak Airport</td><td>2</td><td>2015</td><td>ORIGIN</td><td>8</td></tr><tr><td>Alaska Airlines Inc.</td><td>Adak Airport</td><td>3</td><td>2015</td><td>DESTINATION</td><td>9</td></tr><tr><td>Alaska Airlines Inc.</td><td>Adak Airport</td><td>3</td><td>2015</td><td>ORIGIN</td><td>9</td></tr><tr><td>Alaska Airlines Inc.</td><td>Adak Airport</td><td>4</td><td>2015</td><td>DESTINATION</td><td>9</td></tr><tr><td>Alaska Airlines Inc.</td><td>Adak Airport</td><td>4</td><td>2015</td><td>ORIGIN</td><td>9</td></tr><tr><td>Alaska Airlines Inc.</td><td>Adak Airport</td><td>5</td><td>2015</td><td>DESTINATION</td><td>9</td></tr><tr><td>Alaska Airlines Inc.</td><td>Adak Airport</td><td>5</td><td>2015</td><td>ORIGIN</td><td>9</td></tr><tr><td>Alaska Airlines Inc.</td><td>Adak Airport</td><td>6</td><td>2015</td><td>DESTINATION</td><td>8</td></tr><tr><td>Alaska Airlines Inc.</td><td>Adak Airport</td><td>6</td><td>2015</td><td>ORIGIN</td><td>8</td></tr><tr><td>Alaska Airlines Inc.</td><td>Adak Airport</td><td>7</td><td>2015</td><td>DESTINATION</td><td>9</td></tr><tr><td>Alaska Airlines Inc.</td><td>Adak Airport</td><td>7</td><td>2015</td><td>ORIGIN</td><td>9</td></tr><tr><td>Alaska Airlines Inc.</td><td>Adak Airport</td><td>8</td><td>2015</td><td>DESTINATION</td><td>9</td></tr><tr><td>Alaska Airlines Inc.</td><td>Adak Airport</td><td>8</td><td>2015</td><td>ORIGIN</td><td>9</td></tr><tr><td>Alaska Airlines Inc.</td><td>Albuquerque International Sunport</td><td>1</td><td>2015</td><td>DESTINATION</td><td>31</td></tr><tr><td>Alaska Airlines Inc.</td><td>Albuquerque International Sunport</td><td>1</td><td>2015</td><td>ORIGIN</td><td>31</td></tr><tr><td>Alaska Airlines Inc.</td><td>Albuquerque International Sunport</td><td>2</td><td>2015</td><td>DESTINATION</td><td>28</td></tr><tr><td>Alaska Airlines Inc.</td><td>Albuquerque International Sunport</td><td>2</td><td>2015</td><td>ORIGIN</td><td>28</td></tr><tr><td>Alaska Airlines Inc.</td><td>Albuquerque International Sunport</td><td>3</td><td>2015</td><td>DESTINATION</td><td>31</td></tr><tr><td>Alaska Airlines Inc.</td><td>Albuquerque International Sunport</td><td>3</td><td>2015</td><td>ORIGIN</td><td>31</td></tr><tr><td>Alaska Airlines Inc.</td><td>Albuquerque International Sunport</td><td>4</td><td>2015</td><td>DESTINATION</td><td>30</td></tr><tr><td>Alaska Airlines Inc.</td><td>Albuquerque International Sunport</td><td>4</td><td>2015</td><td>ORIGIN</td><td>30</td></tr><tr><td>Alaska Airlines Inc.</td><td>Albuquerque International Sunport</td><td>5</td><td>2015</td><td>DESTINATION</td><td>31</td></tr><tr><td>Alaska Airlines Inc.</td><td>Albuquerque International Sunport</td><td>5</td><td>2015</td><td>ORIGIN</td><td>31</td></tr><tr><td>Alaska Airlines Inc.</td><td>Albuquerque International Sunport</td><td>6</td><td>2015</td><td>DESTINATION</td><td>30</td></tr><tr><td>Alaska Airlines Inc.</td><td>Albuquerque International Sunport</td><td>6</td><td>2015</td><td>ORIGIN</td><td>30</td></tr><tr><td>Alaska Airlines Inc.</td><td>Albuquerque International Sunport</td><td>7</td><td>2015</td><td>DESTINATION</td><td>31</td></tr><tr><td>Alaska Airlines Inc.</td><td>Albuquerque International Sunport</td><td>7</td><td>2015</td><td>ORIGIN</td><td>31</td></tr><tr><td>Alaska Airlines Inc.</td><td>Albuquerque International Sunport</td><td>8</td><td>2015</td><td>DESTINATION</td><td>31</td></tr><tr><td>Alaska Airlines Inc.</td> ...

# %% [markdown]
# ### Report 2: On time percentage of each airline for the year 2015

# %%
# %sql

select o.AIRLINE, CAST(o.On_Time AS DECIMAL) / CAST(t.TOTAL AS DECIMAL) On_Time_Percentage_For_2015  from 
(SELECT DISTINCT AIRLINE, COUNT(AIRLINE) AS On_Time
FROM (select ar.AIRLINE, f.DEPARTURE_DELAY, f.ARRIVAL_DELAY, f.CANCELLED, f.DIVERTED from airlines ar, flights f where ar.IATA_CODE = f.AIRLINE and f.YEAR ='2015')
WHERE (DEPARTURE_DELAY <=0 or DEPARTURE_DELAY is NULL) and
      (ARRIVAL_DELAY <=0 or ARRIVAL_DELAY is NULL) and
      (CANCELLED = 0) and
      (DIVERTED = 0)
GROUP BY AIRLINE) o, 
(SELECT DISTINCT AIRLINE, COUNT(  AIRLINE ) AS Total
FROM (select ar.AIRLINE, f.DEPARTURE_DELAY, f.ARRIVAL_DELAY, f.CANCELLED, f.DIVERTED from airlines ar, flights f where ar.IATA_CODE = f.AIRLINE and f.YEAR ='2015')
GROUP BY AIRLINE) t 
where o.AIRLINE = t.AIRLINE order by AIRLINE
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AIRLINE</th><th>On_Time_Percentage_For_2015</th></tr></thead><tbody><tr><td>Alaska Airlines Inc.</td><td>0.5914590809</td></tr><tr><td>American Airlines Inc.</td><td>0.50704666237</td></tr><tr><td>American Eagle Airlines Inc.</td><td>0.47954794195</td></tr><tr><td>Atlantic Southeast Airlines</td><td>0.52075711947</td></tr><tr><td>Delta Air Lines Inc.</td><td>0.5625855186</td></tr><tr><td>Frontier Airlines Inc.</td><td>0.43259465233</td></tr><tr><td>Hawaiian Airlines Inc.</td><td>0.54516204063</td></tr><tr><td>JetBlue Airways</td><td>0.50539779395</td></tr><tr><td>Skywest Airlines Inc.</td><td>0.54064094621</td></tr><tr><td>Southwest Airlines Co.</td><td>0.453483488</td></tr><tr><td>Spirit Air Lines</td><td>0.39266638739</td></tr><tr><td>US Airways Inc.</td><td>0.51431950281</td></tr><tr><td>United Air Lines Inc.</td><td>0.38298811853</td></tr><tr><td>Virgin America</td><td>0.4828817215</td></tr></tbody></table></div>

# %% [markdown]
# ### Report 3: Airlines with the largest number of delays

# %%
# %sql

select AIRLINE , sum(air_system_delay) + sum(security_delay) + sum(airline_delay) + sum(late_aircraft_delay) + sum(weather_delay) DELAYS from
(select ar.AIRLINE, 
(CASE 
      WHEN  f.air_system_delay > 0 THEN 1 ELSE 0
END) as air_system_delay, 
(CASE 
      WHEN  f.security_delay > 0 THEN 1 ELSE 0
END) as security_delay, 
(CASE 
      WHEN  f.airline_delay > 0 THEN 1 ELSE 0
END) as airline_delay, 
(CASE 
      WHEN  f.late_aircraft_delay > 0 THEN 1 ELSE 0
END) as late_aircraft_delay,
(CASE 
      WHEN  f.weather_delay > 0 THEN 1 ELSE 0
END) as weather_delay
from airlines ar, flights f where ar.iata_code = f.airline and 
    (not f.air_system_delay is NULL or
     not f.security_delay is NULL or
     not f.airline_delay is NULL or
     not f.late_aircraft_delay is NULL or
     not f.weather_delay is NULL)) group by AIRLINE order by DELAYS desc
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AIRLINE</th><th>DELAYS</th></tr></thead><tbody><tr><td>Southwest Airlines Co.</td><td>304162</td></tr><tr><td>Delta Air Lines Inc.</td><td>140225</td></tr><tr><td>American Airlines Inc.</td><td>135133</td></tr><tr><td>United Air Lines Inc.</td><td>132316</td></tr><tr><td>Atlantic Southeast Airlines</td><td>131228</td></tr><tr><td>Skywest Airlines Inc.</td><td>115166</td></tr><tr><td>American Eagle Airlines Inc.</td><td>86788</td></tr><tr><td>JetBlue Airways</td><td>73104</td></tr><tr><td>US Airways Inc.</td><td>59173</td></tr><tr><td>Spirit Air Lines</td><td>42544</td></tr><tr><td>Frontier Airlines Inc.</td><td>31513</td></tr><tr><td>Alaska Airlines Inc.</td><td>22085</td></tr><tr><td>Virgin America</td><td>11437</td></tr><tr><td>Hawaiian Airlines Inc.</td><td>9761</td></tr></tbody></table></div>

# %% [markdown]
# ### Report 4: Airline with the most unique routes

# %%
# %sql

select airline, sum(Unique_Route) Unique_Routes
from (select distinct ar.airline, 1 as Unique_Route, f.ORIGIN_AIRPORT, f.DESTINATION_AIRPORT from airlines ar, flights f where ar.IATA_CODE = f.AIRLINE) 
group by airline order by sum(Unique_Route) desc
LIMIT 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>airline</th><th>Unique_Routes</th></tr></thead><tbody><tr><td>Atlantic Southeast Airlines</td><td>1351</td></tr></tbody></table></div>

# %% [markdown]
# ### Report 5: Cancellation reasons by airport

# %%
# %sql

SELECT AIRPORT,
concat_ws(', ', collect_list(CANCELLATION_REASON)) as CANCELLATION_REASONS 
FROM (select distinct ap.airport,
(CASE WHEN f.CANCELLATION_REASON = 'A' THEN 'Airline/Carrier'
      WHEN f.CANCELLATION_REASON = 'B' THEN 'Weather'
      WHEN f.CANCELLATION_REASON = 'C' THEN 'National Air System'
      WHEN f.CANCELLATION_REASON = 'D' THEN 'Security'
      ELSE NULL
END) as CANCELLATION_REASON 
from airports ap, flights f where ap.iata_code = f.origin_airport and not f.CANCELLATION_REASON is NULL)
  GROUP BY AIRPORT
  order by airport;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AIRPORT</th><th>CANCELLATION_REASONS</th></tr></thead><tbody><tr><td>Aberdeen Regional Airport</td><td>Airline/Carrier, Weather</td></tr><tr><td>Abilene Regional Airport</td><td>Weather, Airline/Carrier</td></tr><tr><td>Abraham Lincoln Capital Airport</td><td>Weather, Airline/Carrier, National Air System</td></tr><tr><td>Adak Airport</td><td>Weather</td></tr><tr><td>Akron-Canton Regional Airport</td><td>Airline/Carrier, Weather, National Air System</td></tr><tr><td>Albany International Airport</td><td>Airline/Carrier, Weather, National Air System</td></tr><tr><td>Albert J. Ellis Airport</td><td>Airline/Carrier, National Air System, Weather</td></tr><tr><td>Albuquerque International Sunport</td><td>National Air System, Airline/Carrier, Weather</td></tr><tr><td>Alexandria International Airport</td><td>Airline/Carrier, National Air System, Weather</td></tr><tr><td>Alpena County Regional Airport</td><td>Airline/Carrier, Weather, National Air System</td></tr><tr><td>Appleton International Airport</td><td>Weather, National Air System, Airline/Carrier</td></tr><tr><td>Arcata Airport</td><td>Airline/Carrier, Weather</td></tr><tr><td>Arnold Palmer Regional Airport</td><td>Weather, Airline/Carrier, National Air System</td></tr><tr><td>Asheville Regional Airport</td><td>Weather, National Air System, Airline/Carrier</td></tr><tr><td>Aspen-Pitkin County Airport</td><td>Weather, National Air System, Airline/Carrier</td></tr><tr><td>Atlantic City International Airport</td><td>Weather, National Air System, Airline/Carrier</td></tr><tr><td>Augusta Regional Airport (Bush Field)</td><td>Airline/Carrier, Weather</td></tr><tr><td>Austin-Bergstrom International Airport</td><td>Airline/Carrier, National Air System, Weather</td></tr><tr><td>Baltimore-Washington International Airport</td><td>Airline/Carrier, Weather, National Air System</td></tr><tr><td>Bangor International Airport</td><td>Airline/Carrier</td></tr><tr><td>Barkley Regional Airport</td><td>Weather, National Air System, Airline/Carrier</td></tr><tr><td>Barnstable Municipal Airport</td><td>Airline/Carrier</td></tr><tr><td>Baton Rouge Metropolitan Airport</td><td>Weather, National Air System, Airline/Carrier</td></tr><tr><td>Bellingham International Airport</td><td>Airline/Carrier, Weather</td></tr><tr><td>Bemidji Regional Airport</td><td>Weather, Airline/Carrier</td></tr><tr><td>Bert Mooney Airport</td><td>Weather, National Air System</td></tr><tr><td>Bethel Airport</td><td>Weather, Airline/Carrier</td></tr><tr><td>Bill and Hillary Clinton National Airport (Adams Field)</td><td>National Air System, Weather, Airline/Carrier</td></tr><tr><td>Billings Logan International Airport</td><td>Weather, Airline/Carrier, National Air System</td></tr><tr><td>Birmingham-Shuttlesworth International Airport</td><td>Weather, National Air System, Airline/Carrier</td></tr><tr><td>Bishop International Airport</td><td>Weather, National Air System, Airline/Carrier</td></tr><tr><td>Bismarck Municipal Airport</td><td>National Air System, Airline/Carrier, Weather</td></tr><tr><td>Blue Grass Airport</td><td>Airline/Carrier, Weather, National Air System</td></tr><tr><td>Bob Hope Airport (Hollywood Burbank Airport)</td><td>Weather, National Air System, Airline/Carrier</td></tr><tr><td>Boise Airport (Boise Air Terminal)</td><td>Weather, Airline/Carrier, National Air System</td></tr><tr><td>Bozeman Yellowstone International Airport (Gallatin Field Airport)</td><td>Weather, National Air System, Airline/Carrier</td></tr><tr><td>Bradley International Airport</td><td>Airline/Carrier, Weather, National Air System</td></tr><tr><td>Brainerd Lakes Regional Airport</td><td>Weather, Airline/Carrier</td></tr><tr><td>Brownsville/South Padre Island International Airport</td><td>National Air System, Airline/Carrier, Weather</td></tr><tr><td>Brunswick Golden Isles Airport</td><td>Weather, Airline/Carrier</td></tr><t ...

# %% [markdown]
# ### Report 6: Delay reasons by airport

# %%
# %sql

select airport, 
CONCAT(air_system_delay,security_delay,airline_delay,late_aircraft_delay,weather_delay) as Delay_Reasons 
from
(select ap.airport, 
       (CASE WHEN sum(f.air_system_delay) > 0 THEN 'Air_system,' ELSE '' END) as air_system_delay,
       (CASE WHEN sum(f.security_delay) > 0 THEN ' Security,' ELSE '' END) as security_delay,
       (CASE WHEN sum(f.airline_delay) > 0 THEN ' Airline,' ELSE '' END) as airline_delay,
       (CASE WHEN sum(f.late_aircraft_delay) > 0 THEN ' Late_aircraft,' ELSE '' END) as late_aircraft_delay,
       (CASE WHEN sum(f.weather_delay) > 0 THEN ' Weather' ELSE '' END) as weather_delay       
from airports ap, flights f where ap.iata_code = f.origin_airport and 
    (not f.air_system_delay is NULL or
     not f.security_delay is NULL or
     not f.airline_delay is NULL or
     not f.late_aircraft_delay is NULL or
     not f.weather_delay is NULL)
group by ap.airport)
order by airport;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>airport</th><th>Delay_Reasons</th></tr></thead><tbody><tr><td>Aberdeen Regional Airport</td><td>Air_system, Security, Airline, Late_aircraft, Weather</td></tr><tr><td>Abilene Regional Airport</td><td>Air_system, Security, Airline, Late_aircraft, Weather</td></tr><tr><td>Abraham Lincoln Capital Airport</td><td>Air_system, Security, Airline, Late_aircraft, Weather</td></tr><tr><td>Adak Airport</td><td>Air_system, Security, Airline, Late_aircraft, Weather</td></tr><tr><td>Akron-Canton Regional Airport</td><td>Air_system, Airline, Late_aircraft, Weather</td></tr><tr><td>Albany International Airport</td><td>Air_system, Security, Airline, Late_aircraft, Weather</td></tr><tr><td>Albert J. Ellis Airport</td><td>Air_system, Airline, Late_aircraft,</td></tr><tr><td>Albuquerque International Sunport</td><td>Air_system, Security, Airline, Late_aircraft, Weather</td></tr><tr><td>Alexandria International Airport</td><td>Air_system, Security, Airline, Late_aircraft, Weather</td></tr><tr><td>Alpena County Regional Airport</td><td>Air_system, Airline, Late_aircraft, Weather</td></tr><tr><td>Appleton International Airport</td><td>Air_system, Airline, Late_aircraft, Weather</td></tr><tr><td>Arcata Airport</td><td>Air_system, Airline, Late_aircraft,</td></tr><tr><td>Arnold Palmer Regional Airport</td><td>Air_system, Airline, Late_aircraft, Weather</td></tr><tr><td>Asheville Regional Airport</td><td>Air_system, Airline, Late_aircraft, Weather</td></tr><tr><td>Aspen-Pitkin County Airport</td><td>Air_system, Security, Airline, Late_aircraft, Weather</td></tr><tr><td>Atlantic City International Airport</td><td>Air_system, Security, Airline, Late_aircraft, Weather</td></tr><tr><td>Augusta Regional Airport (Bush Field)</td><td>Air_system, Airline, Late_aircraft, Weather</td></tr><tr><td>Austin-Bergstrom International Airport</td><td>Air_system, Security, Airline, Late_aircraft, Weather</td></tr><tr><td>Baltimore-Washington International Airport</td><td>Air_system, Security, Airline, Late_aircraft, Weather</td></tr><tr><td>Bangor International Airport</td><td>Air_system, Airline, Late_aircraft, Weather</td></tr><tr><td>Barkley Regional Airport</td><td>Air_system, Airline, Late_aircraft, Weather</td></tr><tr><td>Barnstable Municipal Airport</td><td>Air_system, Airline, Late_aircraft,</td></tr><tr><td>Baton Rouge Metropolitan Airport</td><td>Air_system, Airline, Late_aircraft, Weather</td></tr><tr><td>Bellingham International Airport</td><td>Air_system, Airline, Late_aircraft, Weather</td></tr><tr><td>Bemidji Regional Airport</td><td>Air_system, Airline, Late_aircraft, Weather</td></tr><tr><td>Bert Mooney Airport</td><td>Air_system, Airline, Late_aircraft, Weather</td></tr><tr><td>Bethel Airport</td><td>Air_system, Security, Airline, Late_aircraft, Weather</td></tr><tr><td>Bill and Hillary Clinton National Airport (Adams Field)</td><td>Air_system, Airline, Late_aircraft, Weather</td></tr><tr><td>Billings Logan International Airport</td><td>Air_system, Airline, Late_aircraft, Weather</td></tr><tr><td>Birmingham-Shuttlesworth International Airport</td><td>Air_system, Airline, Late_aircraft, Weather</td></tr><tr><td>Bishop International Airport</td><td>Air_system, Airline, Late_aircraft, Weather</td></tr><tr><td>Bismarck Municipal Airport</td><td>Air_system, Security, Airline, Late_aircraft, Weather</td></tr><tr><td>Blue Grass Airport</td><td>Air_system, Security, Airline, Late_aircraft, Weather</td></tr><tr><td>Bob Hope Airport (Hollywood Burbank Airport)</td><td>Air_system, Security, Airline, Late_aircraft, Weather</td></tr><tr><td>Boise Airport (Boise Air Terminal)</td><td>Air_system, Security, Airline, Late_aircraft, Weather</td></tr><tr><td>Bozeman Yellowstone International Airport (Gallatin Field Airport)</td><td>Air_system, Airline, Late_aircraft, Weather</td></tr><tr><td>Bradley International Airport</td><td>Air_system, Security, Air ...

# %% [markdown]
# ## 3. Load the Databricks Tables in Snowflake

# %% [markdown]
# #### Python Snowflake Connection Configuration

# %%
options = {
  "sfUrl": "https://es55682.us-central1.gcp.snowflakecomputing.com",
  "sfUser": "",
  "sfPassword": "",
  "sfDatabase": "USER_JOHN",
  "sfSchema": "PUBLIC",
  "sfWarehouse": "INTERVIEW_WH"
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# #### Scala Snowflake Connection Configuration

# %%
# %scala

val options = Map(
  "sfUrl" -> "https://es55682.us-central1.gcp.snowflakecomputing.com",
  "sfUser" -> "",
  "sfPassword" -> "",
  "sfDatabase" -> "USER_JOHN",
  "sfSchema" -> "PUBLIC",
  "sfWarehouse" -> "INTERVIEW_WH"
)

import net.snowflake.spark.snowflake.Utils

Utils.runQuery(options, """CREATE SCHEMA IF NOT EXISTS PUBLIC""")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">options: scala.collection.immutable.Map[String,String] = Map(sfUrl -&gt; https://es55682.us-central1.gcp.snowflakecomputing.com, sfSchema -&gt; PUBLIC, sfPassword -&gt; eE15ib13lr0D8adY, sfUser -&gt; jthom423, sfWarehouse -&gt; INTERVIEW_WH, sfDatabase -&gt; USER_JOHN)
# import net.snowflake.spark.snowflake.Utils
# res0: java.sql.ResultSet = net.snowflake.client.jdbc.SnowflakeResultSetV1@22f1ed28
# </div>

# %% [markdown]
# #### Delete existing tables in Snowflake

# %%
# %scala
import net.snowflake.spark.snowflake.Utils
Utils.runQuery(options, """DROP TABLE IF EXISTS airlines""")
Utils.runQuery(options, """DROP TABLE IF EXISTS airports""")
Utils.runQuery(options, """DROP TABLE IF EXISTS flights""")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">import net.snowflake.spark.snowflake.Utils
# res1: java.sql.ResultSet = net.snowflake.client.jdbc.SnowflakeResultSetV1@4f4ded0f
# </div>

# %% [markdown]
# #### Load Airlines Databricks table into Snowflake

# %%
airlines_df.write \
  .format("snowflake") \
  .options(**options) \
  .option("dbtable", "airlines") \
  .save()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = spark.read \
  .format("snowflake") \
  .options(**options) \
  .option("dbtable", "airlines") \
  .load()

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>IATA_CODE</th><th>AIRLINE</th></tr></thead><tbody><tr><td>UA</td><td>United Air Lines Inc.</td></tr><tr><td>AA</td><td>American Airlines Inc.</td></tr><tr><td>US</td><td>US Airways Inc.</td></tr><tr><td>F9</td><td>Frontier Airlines Inc.</td></tr><tr><td>B6</td><td>JetBlue Airways</td></tr><tr><td>OO</td><td>Skywest Airlines Inc.</td></tr><tr><td>AS</td><td>Alaska Airlines Inc.</td></tr><tr><td>NK</td><td>Spirit Air Lines</td></tr><tr><td>WN</td><td>Southwest Airlines Co.</td></tr><tr><td>DL</td><td>Delta Air Lines Inc.</td></tr><tr><td>EV</td><td>Atlantic Southeast Airlines</td></tr><tr><td>HA</td><td>Hawaiian Airlines Inc.</td></tr><tr><td>MQ</td><td>American Eagle Airlines Inc.</td></tr><tr><td>VX</td><td>Virgin America</td></tr></tbody></table></div>

# %% [markdown]
# #### Load Airports Databricks table into Snowflake

# %%
airports_df.write \
  .format("snowflake") \
  .options(**options) \
  .option("dbtable", "airports") \
  .save()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = spark.read \
  .format("snowflake") \
  .options(**options) \
  .option("dbtable", "airports") \
  .load()

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>IATA_CODE</th><th>AIRPORT</th><th>CITY</th><th>STATE</th><th>COUNTRY</th><th>LATITUDE</th><th>LONGITUDE</th></tr></thead><tbody><tr><td>ABE</td><td>Lehigh Valley International Airport</td><td>Allentown</td><td>PA</td><td>USA</td><td>40.65236</td><td>-75.4404</td></tr><tr><td>ABI</td><td>Abilene Regional Airport</td><td>Abilene</td><td>TX</td><td>USA</td><td>32.41132</td><td>-99.6819</td></tr><tr><td>ABQ</td><td>Albuquerque International Sunport</td><td>Albuquerque</td><td>NM</td><td>USA</td><td>35.04022</td><td>-106.60919</td></tr><tr><td>ABR</td><td>Aberdeen Regional Airport</td><td>Aberdeen</td><td>SD</td><td>USA</td><td>45.44906</td><td>-98.42183</td></tr><tr><td>ABY</td><td>Southwest Georgia Regional Airport</td><td>Albany</td><td>GA</td><td>USA</td><td>31.53552</td><td>-84.19447</td></tr><tr><td>ACK</td><td>Nantucket Memorial Airport</td><td>Nantucket</td><td>MA</td><td>USA</td><td>41.25305</td><td>-70.06018</td></tr><tr><td>ACT</td><td>Waco Regional Airport</td><td>Waco</td><td>TX</td><td>USA</td><td>31.61129</td><td>-97.23052</td></tr><tr><td>ACV</td><td>Arcata Airport</td><td>Arcata/Eureka</td><td>CA</td><td>USA</td><td>40.97812</td><td>-124.10862</td></tr><tr><td>ACY</td><td>Atlantic City International Airport</td><td>Atlantic City</td><td>NJ</td><td>USA</td><td>39.45758</td><td>-74.57717</td></tr><tr><td>ADK</td><td>Adak Airport</td><td>Adak</td><td>AK</td><td>USA</td><td>51.87796</td><td>-176.64603</td></tr><tr><td>ADQ</td><td>Kodiak Airport</td><td>Kodiak</td><td>AK</td><td>USA</td><td>57.74997</td><td>-152.49386</td></tr><tr><td>AEX</td><td>Alexandria International Airport</td><td>Alexandria</td><td>LA</td><td>USA</td><td>31.32737</td><td>-92.54856</td></tr><tr><td>AGS</td><td>Augusta Regional Airport (Bush Field)</td><td>Augusta</td><td>GA</td><td>USA</td><td>33.36996</td><td>-81.9645</td></tr><tr><td>AKN</td><td>King Salmon Airport</td><td>King Salmon</td><td>AK</td><td>USA</td><td>58.6768</td><td>-156.64922</td></tr><tr><td>ALB</td><td>Albany International Airport</td><td>Albany</td><td>NY</td><td>USA</td><td>42.74812</td><td>-73.80298</td></tr><tr><td>ALO</td><td>Waterloo Regional Airport</td><td>Waterloo</td><td>IA</td><td>USA</td><td>42.55708</td><td>-92.40034</td></tr><tr><td>AMA</td><td>Rick Husband Amarillo International Airport</td><td>Amarillo</td><td>TX</td><td>USA</td><td>35.21937</td><td>-101.70593</td></tr><tr><td>ANC</td><td>Ted Stevens Anchorage International Airport</td><td>Anchorage</td><td>AK</td><td>USA</td><td>61.17432</td><td>-149.99619</td></tr><tr><td>APN</td><td>Alpena County Regional Airport</td><td>Alpena</td><td>MI</td><td>USA</td><td>45.07807</td><td>-83.56029</td></tr><tr><td>ASE</td><td>Aspen-Pitkin County Airport</td><td>Aspen</td><td>CO</td><td>USA</td><td>39.22316</td><td>-106.86885</td></tr><tr><td>ATL</td><td>Hartsfield-Jackson Atlanta International Airport</td><td>Atlanta</td><td>GA</td><td>USA</td><td>33.64044</td><td>-84.42694</td></tr><tr><td>ATW</td><td>Appleton International Airport</td><td>Appleton</td><td>WI</td><td>USA</td><td>44.25741</td><td>-88.51948</td></tr><tr><td>AUS</td><td>Austin-Bergstrom International Airport</td><td>Austin</td><td>TX</td><td>USA</td><td>30.19453</td><td>-97.66987</td></tr><tr><td>AVL</td><td>Asheville Regional Airport</td><td>Asheville</td><td>NC</td><td>USA</td><td>35.43619</td><td>-82.54181</td></tr><tr><td>AVP</td><td>Wilkes-Barre/Scranton International Airport</td><td>Wilkes-Barre/Scranton</td><td>PA</td><td>USA</td><td>41.33815</td><td>-75.72427</td></tr><tr><td>AZO</td><td>Kalamazoo/Battle Creek International Airport</td><td>Kalamazoo</td><td>MI</td><td>USA</td><td>42.23488</td><td>-85.55206</td></tr><tr><td>BDL</td><td>Bradley International Airport</td><td>Windsor Locks</td><td>CT</td><td>USA</td><td>41.93887</td><td>-72.68323</td></tr><tr><td>BET</td><td>Bethel Airport</td><td>Bethel</td><td>AK</td><td>USA</td><td>6 ...

# %% [markdown]
# #### Load Flights Databricks table into Snowflake

# %%
flights_df.write \
  .format("snowflake") \
  .options(**options) \
  .option("dbtable", "flights") \
  .save()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = spark.read \
  .format("snowflake") \
  .options(**options) \
  .option("dbtable", "flights") \
  .load()

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>YEAR</th><th>MONTH</th><th>DAY</th><th>DAY_OF_WEEK</th><th>AIRLINE</th><th>TAIL_NUMBER</th><th>ORIGIN_AIRPORT</th><th>DESTINATION_AIRPORT</th><th>DEPARTURE_DELAY</th><th>TAXI_OUT</th><th>SCHEDULED_TIME</th><th>ELAPSED_TIME</th><th>AIR_TIME</th><th>DISTANCE</th><th>WHEELS_ON</th><th>TAXI_IN</th><th>SCHEDULED_ARRIVAL</th><th>DIVERTED</th><th>CANCELLED</th><th>CANCELLATION_REASON</th><th>AIR_SYSTEM_DELAY</th><th>SECURITY_DELAY</th><th>AIRLINE_